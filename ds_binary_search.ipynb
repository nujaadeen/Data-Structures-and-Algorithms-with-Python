# %%
from jovian.pythondsa import evaluate_test_case, evaluate_test_cases

# %%
# input ---> cards array, quiry 
# output ----> position

tests = []  # possible test cases

# %%
cards = [98, 54, 50, 45, 32, 14, 3]
query = 14
position = 5
test = {
    'input':{'cards': cards, 'query':query},
    'output':position
}

# %%
tests.append(test)

# %%
cards1 = [98, 54, 50, 45, 32, 14, 3]
query1 = 54
position1 = 1
test1 = {
    'input':{'cards': cards1, 'query':query1},
    'output':position1
} 
tests.append(test1)

cards2 = [3, 2, -12, -15]
query2 = 3
position2 = 0
test2 = {
    'input':{'cards': cards2, 'query':query2},
    'output':position2
} 
tests.append(test2)

cards3 = [3, 2, -12, -125]
query3 = -125
position3 = 3
test3 = {
    'input':{'cards': cards3, 'query':query3},
    'output':position3
} 
tests.append(test3)

cards4 = [5]
query4 = 5
position4 = 0
test4 = {
    'input':{'cards': cards4, 'query':query4},
    'output':position4
} 
tests.append(test4)

cards5 = [3, 2, -12, -15]
query5 = -3
position5 = -1
test5 = {
    'input':{'cards': cards5, 'query':query5},
    'output':position5
} 
tests.append(test5)

cards6 = []
query6 = -3
position6 = -1
test6 = {
    'input':{'cards': cards6, 'query':query6},
    'output':position6
} 
tests.append(test6)

cards7 = [3,3,3, 2,2,2 , 1,1, 0, -12,-12, -15,-15,-15]
query7 = 0
position7 = 8
test7 = {
    'input':{'cards': cards7, 'query':query7},
    'output':position7
} 
tests.append(test7)

cards8 = [3,3,3, 2,2,2 , 1,1, 0, -12,-12, -15,-15,-15]
query8 = 2
position8 = 3
test8 = {
    'input':{'cards': cards8, 'query':query8},
    'output':position8
} 
tests.append(test8)

# %%
tests
# Out:
# [{'input': {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 14}, 'output': 5},
#  {'input': {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 54}, 'output': 1},
#  {'input': {'cards': [3, 2, -12, -15], 'query': 3}, 'output': 0},
#  {'input': {'cards': [3, 2, -12, -125], 'query': -125}, 'output': 3},
#  {'input': {'cards': [5], 'query': 5}, 'output': 0},
#  {'input': {'cards': [3, 2, -12, -15], 'query': -3}, 'output': -1},
#  {'input': {'cards': [], 'query': -3}, 'output': -1},
#  {'input': {'cards': [3, 3, 3, 2, 2, 2, 1, 1, 0, -12, -12, -15, -15, -15],
#    'query': 0},
#   'output': 8},
#  {'input': {'cards': [3, 3, 3, 2, 2, 2, 1, 1, 0, -12, -12, -15, -15, -15],
#    'query': 2},
#   'output': 3}]

# %%
def locate_card(cards, query):
    lo, hi = 0, len(cards)-1
    
    while(lo<=hi):
        mid_idx = (lo + hi) // 2
        mid_val = cards[mid_idx]

        print(f"lo: {lo}, hi: {hi}, mid_idx: {mid_idx}, mid_val: {mid_val}")

        if(mid_val == query):
            return mid_idx
        elif(mid_val < query):
            hi = mid_idx - 1
        elif(mid_val > query):
            lo = mid_idx + 1
    return -1

# %%
evaluate_test_cases(locate_card, tests)
# Out:
# TEST CASE #0
# lo: 0, hi: 6, mid_idx: 3, mid_val: 45
# lo: 4, hi: 6, mid_idx: 5, mid_val: 14
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 14}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.009 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# lo: 0, hi: 6, mid_idx: 3, mid_val: 45
# lo: 0, hi: 2, mid_idx: 1, mid_val: 54
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 54}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# lo: 0, hi: 3, mid_idx: 1, mid_val: 2
# lo: 0, hi: 0, mid_idx: 0, mid_val: 3
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# lo: 0, hi: 3, mid_idx: 1, mid_val: 2
# lo: 2, hi: 3, mid_idx: 2, mid_val: -12
# lo: 3, hi: 3, mid_idx: 3, mid_val: -125
#
# Input:
# {'cards': [3, 2, -12, -125], 'query': -125}
#
# ...

# %%
def locate_card_v2(cards, query):
    lo, hi = 0, len(cards)-1
    
    while(lo<=hi):
        mid_idx = (lo + hi) // 2
        mid_val = cards[mid_idx]

        # print(f"lo: {lo}, hi: {hi}, mid_idx: {mid_idx}, mid_val: {mid_val}")

        if(mid_val == query):
            if(mid_idx-1 >=0 and cards[mid_idx-1]==mid_val):
                hi = mid_idx - 1
            else:
                return mid_idx
        elif(mid_val < query):
            hi = mid_idx - 1
        elif(mid_val > query):
            lo = mid_idx + 1
    return -1

# %%
evaluate_test_cases(locate_card_v2, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 14}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 54}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, 2, -12, -125], 'query': -125}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [5], 'query': 5}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': -3}
#
# Expected Output:
# ...

# %%
def locate_card_linear(cards, query):
    position = 0 
    while (position < len(cards)):
        if(cards[position] == query):
            return position
        else:
            position += 1
    return -1

# %%
evaluate_test_cases(locate_card_linear, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 14}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 54}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, 2, -12, -125], 'query': -125}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [5], 'query': 5}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': -3}
#
# Expected Output:
# ...

# %%
large_test = {
    'input':{'cards': list(range(10000000, 0, -1)), 'query':2},
    'output':9999998
}

# %%
# O(n)
result, passed, runtime = evaluate_test_case(locate_card_linear, large_test, display=False)
print(f'result: {result} \npassed: {passed} \nruntime: {runtime}')
# Out:
# result: 9999998
# passed: True
# runtime: 490.47

# %%
# O(log(n))
result1, passed1, runtime1 = evaluate_test_case(locate_card_v2, large_test, display=False)
print(f'result: {result1} \npassed: {passed1} \nruntime: {runtime1}')
# Out:
# result: 9999998
# passed: True
# runtime: 0.008

# %% [markdown]
# Generic Binary Search

# %%
def binary_search(lo, hi, condition):
    while(lo<=hi):
        mid = (lo + hi) // 2
        result = condition(mid)
        if(result == 'found'):
            return mid
        elif(result == 'left'):
            hi = mid - 1
        elif(result == 'right'):
            lo = mid + 1 
    return -1

# %%
def locate_card_v3(cards, query):
    def condition(mid):
        if (cards[mid] == query):
            if (mid > 0 and cards[mid-1] == query):
                return 'left'
            else:
                return 'found'
        elif (cards[mid]  < query):
            return 'left'
        elif (cards[mid]  > query):
            return 'right'
    
    return binary_search(0 ,len(cards) - 1, condition)

# %%
evaluate_test_cases(locate_card_v3, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 14}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [98, 54, 50, 45, 32, 14, 3], 'query': 54}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': 3}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [3, 2, -12, -125], 'query': -125}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [5], 'query': 5}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [3, 2, -12, -15], 'query': -3}
#
# Expected Output:
# ...

# %% [markdown]
# #### Question: Given an array of integers nums sorted in ascending order, find the starting and ending position of a given number.

# %%
def start_pos(nums, target):
    def condition(mid):
        if (nums[mid] == target):
            if (mid > 0 and nums[mid-1] == target):
                return 'left'
            else:
                return 'found'
        elif (nums[mid] < target):
            return 'right'
        elif (nums[mid] > target):
            return 'left'
    return binary_search(0, len(nums) -1, condition)

# %%
def end_pos(nums, target):
    def condition(mid):
        if (nums[mid] == target):
            if (mid > 0 and nums[mid+1] == target):
                return 'right'
            else:
                return 'found'
        elif (nums[mid] < target):
            return 'right'
        elif (nums[mid] > target):
            return 'left'
    return binary_search(0, len(nums) -1, condition)

# %%
def start_end_pos(nums, target):
    start = start_pos(nums, target)
    end = end_pos(nums, target)

    return start, end

# %% [markdown]
# https://leetcode.com/problems/find-first-and-last-position-of-element-in-sorted-array/submissions/

# %% [markdown]
# #### Problem - Rotated Lists

# %% [markdown]
# You are given list of numbers, obtained by rotating a sorted list an unknown number of times. Write a function to determine the minimum number of times the original sorted list was rotated to obtain the given list. Your function should have the worst-case complexity of O(log N), where N is the length of the list. You can assume that all the numbers in the list are unique.
# Example: The list [5, 6, 9, 0, 2, 3, 4] was obtained by rotating the sorted list [0, 2, 3, 4, 5, 6, 9] 3 times.
# We define "rotating a list" as removing the last element of the list and adding it before the first element. E.g. rotating the list [3, 2, 4, 1] produces [1, 3, 2, 4].
# "Sorted list" refers to a list where the elements are arranged in the increasing order e.g. [1, 3, 5, 7].

# %%
def binary_search_2(lo, hi, condition):
    while(lo<=hi):
        mid = (lo + hi) // 2
        result = condition(mid)
        if(result == 'found'):
            return mid
        elif(result == 'left'):
            hi = mid - 1
        elif(result == 'right'):
            lo = mid + 1 
    return 0

# %%
from jovian.pythondsa import binary_search

# %%
def count_rotation(nums):
    def condition(mid):
        if((mid > 0  and (nums[mid] < nums[mid-1])) or len(nums) <= 1):
            return 'found'
        elif(nums[mid] < nums[len(nums)-1]):
            return 'left'
        elif(nums[mid] > nums[len(nums)-1]):
            return 'right'
    return binary_search(0, len(nums)-1, condition) if (binary_search(0, len(nums)-1, condition) != -1) else 0

# %%
tests2 = []

# %%
nums = [5, 6, 9 ,0 ,2, 3, 4]
position = 3
test2_1 = {
    'input':{'nums': nums},
    'output':position
} 
tests2.append(test2_1)

nums2 = [9 ,0 ,2, 3, 4, 5, 6, 7, 8]
position2 = 1
test2_2 = {
    'input':{'nums': nums2},
    'output':position2
} 
tests2.append(test2_2)

nums3 = [0 ,2, 3, 4]
position3 = 0
test2_3 = {
    'input':{'nums': nums3},
    'output':position3
} 
tests2.append(test2_3)

nums4 = [0, 2, 3, 4, 5, 6, 7, 8, -1]
position4 = 8
test2_4 = {
    'input':{'nums': nums4},
    'output':position4
} 
tests2.append(test2_4)

nums5 = [2]
position5 = 0
test2_5 = {
    'input':{'nums': nums5},
    'output':position5
} 
tests2.append(test2_5)

nums6 = []
position6 = 0
test2_6 = {
    'input':{'nums': nums6},
    'output':position6
} 
tests2.append(test2_6)

# %%
tests2
# Out:
# [{'input': {'nums': [5, 6, 9, 0, 2, 3, 4]}, 'output': 3},
#  {'input': {'nums': [9, 0, 2, 3, 4, 5, 6, 7, 8]}, 'output': 1},
#  {'input': {'nums': [0, 2, 3, 4]}, 'output': 0},
#  {'input': {'nums': [0, 2, 3, 4, 5, 6, 7, 8, -1]}, 'output': 8},
#  {'input': {'nums': [2]}, 'output': 0},
#  {'input': {'nums': []}, 'output': 0}]

# %%
evaluate_test_cases(count_rotation, tests2)
# Out:
# TEST CASE #0
#
# Input:
# {'nums': [5, 6, 9, 0, 2, 3, 4]}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'nums': [9, 0, 2, 3, 4, 5, 6, 7, 8]}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'nums': [0, 2, 3, 4]}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'nums': [0, 2, 3, 4, 5, 6, 7, 8, -1]}
#
# Expected Output:
# 8
#
#
# Actual Output:
# 8
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'nums': [2]}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'nums': []}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# ...

# %% [markdown]
# #### Searching in a Rotated List

# %%
def count_rotation(nums):
    def condition(mid):
        if((mid > 0  and (nums[mid] < nums[mid-1])) or len(nums) <= 1):
            return 'found'
        elif(nums[mid] < nums[len(nums)-1]):
            return 'left'
        elif(nums[mid] > nums[len(nums)-1]):
            return 'right'
    return binary_search(0, len(nums)-1, condition) if (binary_search(0, len(nums)-1, condition) != -1) else 0

# %%
def array_binary_search(nums, target):  
    def condition(mid):
        print(nums[mid])
        if(nums[mid] == target):
            if(mid>0 and nums[mid] == nums[mid-1]):
                return 'left'
            else:
                return 'found'
        elif(nums[mid] > target):
            return 'left'
        elif(nums[mid] < target):
            return 'right'

    return binary_search(0, len(nums)-1, condition)

# %%
def rotated_binary_search(nums, target):
    bound = count_rotation(nums)
    nums_1 = nums[:bound]
    nums_2 = nums[bound:]
    print(nums_1, nums_2)
    loc_1 = array_binary_search(nums_1, target)
    loc_2 = array_binary_search(nums_2, target)

    if (loc_1 != -1):
        return loc_1
    elif (loc_2 != -1):
        return loc_2 + bound
    else:
        return -1

# %%
rotated_binary_search([2,5,6,0,0,1,2], 3)
# Out:
# [2, 5, 6] [0, 0, 1, 2]
# 5
# 2
# 0
# 1
# 2
# -1

# %%
rotated_binary_search([2,5,6,0,0,1,2], 3)
# Out:
# 'false'

# %%
def binary_search(lo, hi, condition):
    while(lo<=hi):
        mid = (lo + hi) // 2
        result = condition(mid)
        if(result == 'found'):
            return mid
        elif(result == 'left'):
            hi = mid - 1
        elif(result == 'right'):
            lo = mid + 1 
    return -1

def array_binary_search(nums, target):  
    def condition(mid):
        print(nums[mid])
        if(nums[mid] == target):
            if(mid>0 and nums[mid] == nums[mid-1]):
                return 'left'
            else:
                return 'found'
        elif(nums[mid] > target):
            return 'left'
        elif(nums[mid] < target):
            return 'right'

    return binary_search(0, len(nums)-1, condition)


def rotated_binary_search(nums, target):
    lo, hi = 0, len(nums) - 1
    bound = 0
    while(lo<=hi):
        print(f'lo: {lo}, hi: {hi}')
        mid = (lo+hi) // 2
        mid_val = nums[mid]
        print(nums[lo:hi], nums[mid])
        if(mid>0 and nums[mid] == target):
            return True
        elif(nums[hi] == nums[mid] == nums[lo]):
            lo = lo + 1
            hi = hi - 1
        elif(nums[mid] <= nums[hi]):
            if (nums[mid]<target<= nums[hi]):
                lo = mid + 1
            else:
                hi = mid - 1
        else:
            if (nums[hi]<target<=nums[mid]):
                hi = mid + 1
            else:
                lo = mid - 1
    return False
    
    nums_1 = nums[:bound]
    nums_2 = nums[bound:]

    loc_1 = array_binary_search(nums_1, target)
    loc_2 = array_binary_search(nums_2, target)
        


    if (loc_1 != -1):
        return True
    elif (loc_2 != -1):
        return True
    else:
        return False

# %%
rotated_binary_search([1,2,3,3,0,0,0], 0)
# Out:
# lo: 0, hi: 6
# [1, 2, 3, 3, 0, 0] 3
# lo: 3, hi: 6
# [3, 0, 0] 0
# 2
# 1
# 0
# 0
# True
